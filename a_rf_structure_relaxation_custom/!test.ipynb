# %%
from e3nn import o3

# 这就像给数据贴上"类型标签"
irreps = o3.Irreps("12x0e + 1x1o + 10x0e")

print(irreps)
# 输出: 12x0e+11x0e+1x1o
# 12个偶标量 + 11个偶标量 + 1个奇向量
# Out:
# 12x0e+1x1o+10x0e

# %%
# !pkill -f tensorboard
# !tensorboard --logdir outputs --port 6006 --host 0.0.0.0
